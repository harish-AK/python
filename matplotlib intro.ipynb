# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x=np.linspace(5,50,10)
y=x*x+x

# %%
x
# Out:
# array([ 5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])

# %%
y
# Out:
# array([  30.,  110.,  240.,  420.,  650.,  930., 1260., 1640., 2070.,
#        2550.])

# %%
plt.plot(x,y,'r') # r is red
plt.xlabel('numbers between 5 and 50 ')
plt.ylabel('y has cube of x')
plt.title('cube of numbers')
plt.show()
